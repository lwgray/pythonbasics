# %% [markdown]
# # This Notebook is to showcase very simple creation of Pandas and Matplotlib visualizations

# %% [markdown]
# ## Quick vis with just pandas
#
# Pandas includes some built-in visualization methods against dataframes for common plots. It is as simple as calling the `hist()` or `plot()` method on a dataframe to get a visualization.

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('iris.csv')

# %%
df.plot('Sepal Length', 'Sepal Width', kind="scatter")

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11a6028d0>,
# ...
#       dtype=object)

# %%
df[df['Species'] == 'virginica'].hist(column=['Sepal Width'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11cb89240>]],
#       dtype=object)

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Sepal Width'], df['Sepal Length'])
plt.xlabel('Sepal Width')
plt.ylabel('Sepal Length')
plt.title('Sepal Width vs Sepal Length')
plt.show()

# %% [markdown]
# ## Another example : GDP over the Years for Different Countries

# %%
df = pd.read_csv('gdp_time_series', skiprows=3, delim_whitespace=True)

# %%
plt.plot(df['YEAR'],df['AUSTRIA'])
plt.title('Austria')
plt.ylabel('Per Capita Annual GDP')
plt.xlabel('Years')
plt.show()
